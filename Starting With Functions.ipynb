# %%
print("Hello World")
# Out:
# Hello World

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int(x=0) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
# ...

# %%
result = print("hey")
# Out:
# hey

# %%
print(result)
# Out:
# None

# %%
#max((None, 4))

# %%
print(int('42'))
# Out:
# 42

# %%
# Rubber Duck  explain it

# %%
# import math

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
help(math.pi)
# Out:
# Help on float object:
#
# class float(object)
#  |  float(x) -> floating point number
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(...)
#  |      float.__format__(format_spec) -> string
#  |
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getformat__(...) from builtins.type
# ...

# %%
# from math import pi
# print(pi)

# import math as m
# print(m.pi)
# Out:
# 3.141592653589793
# 3.141592653589793

# %%
val = input("Do you want to fail: y or n?")
print("type of input: ", type(val))
if (val == 'y'):
    help(math)
else:
    import math
    help(math)
# Out:
# Do you want to fail: y or n?n
# type of input:  <class 'str'>
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.6/library/math
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(...)
#         acosh(x)
#
#         Return the inverse hyperbolic cosine of x.
#
#     asin(...)
#         asin(x)
#
#         Return the arc sine (measured in radians) of x.
#
#     asinh(...)
#         asinh(x)
#
# ...

# %%
import pandas
dataframe = pandas.read_csv('Data/gapminder_gdp_europe.csv')
dataframe.groupby("gdpPercap_1952").min()
# Out:
#                                country  gdpPercap_1957  gdpPercap_1962  \
# gdpPercap_1952
# 973.533195      Bosnia and Herzegovina     1353.989176     1709.683679
# 1601.056136                    Albania     1942.284244     2312.888958
# 1969.100980                     Turkey     2218.754257     2322.869908
# 2444.286648                   Bulgaria     3008.670727     4254.337839
# 2647.585601                 Montenegro     3682.259903     4649.593785
# 3068.319867                   Portugal     3774.571743     4727.954889
# 3119.236520                    Croatia     4338.231617     5477.890018
# 3144.613186                    Romania     3943.370225     4734.997586
# 3530.690067                     Greece     4916.299889     6017.190733
# 3581.459448                     Serbia     4981.090891     6289.629157
# 3834.034742                      Spain     4564.802410     5693.843879
# 4029.329699                     Poland     4734.253019     5338.752143
# ...

# %%
30*13*8
# Out:
# 3120

# %%
#A Dataframe consists of a number of Series
dataframe = pandas.read_csv('data/gapminder_gdp_europe.csv', index_col = 'country')

# %%
interesting = dataframe.loc['Switzerland':, 'gdpPercap_1987':'gdpPercap_2001']
#interesting.describe()
interesting
# Out:
#                 gdpPercap_1987  gdpPercap_1992  gdpPercap_1997
# country
# Switzerland       30281.704590    31871.530300    32135.323010
# Turkey             5089.043686     5678.348271     6601.429915
# United Kingdom    21664.787670    22705.092540    26074.531360

# %%
dataframe
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
global_mean = dataframe.mean().mean()
global_mean
# Out:
# 14469.475533302224

# %%
greater_than_mean_mask = dataframe > global_mean

# %%
dataframe[greater_than_mean_mask].describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count         1.00000         1.00000          1.0000        6.000000
# mean      14734.23275     17909.48973      20431.0927    16772.067660
# std               NaN             NaN             NaN     3085.921587
# min       14734.23275     17909.48973      20431.0927    14745.625610
# 25%       14734.23275     17909.48973      20431.0927    15284.535568
# 50%       14734.23275     17909.48973      20431.0927    15650.231295
# 75%       14734.23275     17909.48973      20431.0927    16255.710160
# max       14734.23275     17909.48973      20431.0927    22966.144320
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       11.000000       14.000000       17.000000       18.000000
# mean     18254.860658    19372.900251    20212.925256    22154.318577
# std       3203.023358     3241.180953     3723.970000     4674.960152
# ...
